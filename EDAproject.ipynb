# %% [markdown]
# # Ecommerce customer behaviour analysis
# Exploratory Data Analysis (EDA) is a crucial step in understanding and interpreting data before diving into more complex analyses or predictive modeling. For eCommerce customer behavior analysis, EDA helps in uncovering patterns, trends, and insights that can guide decision-making. Here’s a step-by-step approach to implementing EDA in this context:

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('ecommerce_customer_data_custom_ratios.csv')
df.head()
# Out:
#    Customer ID        Purchase Date Product Category  Product Price  Quantity  \
# 0        46251  2020-09-08 09:38:32      Electronics             12         3
# 1        46251  2022-03-05 12:56:35             Home            468         4
# 2        46251  2022-05-23 18:18:01             Home            288         2
# 3        46251  2020-11-12 13:13:29         Clothing            196         1
# 4        13593  2020-11-27 17:55:11             Home            449         1
#
#    Total Purchase Amount Payment Method  Customer Age  Returns  \
# 0                    740    Credit Card            37      0.0
# 1                   2739         PayPal            37      0.0
# 2                   3196         PayPal            37      0.0
# 3                   3509         PayPal            37      0.0
# 4                   3452    Credit Card            49      0.0
#
#          Customer Name  Age  Gender  Churn
# 0  Christine Hernandez   37    Male      0
# ...

# %% [markdown]
#  Here we are Reading the ecommerce_customer_data_custom_ratios.csv file with the help of pandas

# %%
df.tail()
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 249995        33308  2023-08-10 13:39:06         Clothing            279
# 249996        48835  2021-11-23 01:30:42             Home             27
# 249997        21019  2020-07-02 14:04:48             Home             17
# 249998        49234  2020-12-30 02:02:40            Books            398
# 249999        16971  2021-03-13 16:28:35      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# 249995         2                   2187         PayPal            55      1.0
# 249996         1                   3615    Credit Card            42      1.0
# 249997         5                   2466           Cash            41      0.0
# 249998         2                   3668         Crypto            34      0.0
# 249999         4                   2370           Cash            36      1.0
#
#           Customer Name  Age  Gender  Churn
# ...

# %% [markdown]
# we use the tail() command to retrieve the first 5 rows of our data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          250000 non-null  object
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   Payment Method         250000 non-null  object
#  7   Customer Age           250000 non-null  int64
#  8   Returns                202404 non-null  float64
#  9   Customer Name          250000 non-null  object
#  10  Age                    250000 non-null  int64
#  11  Gender                 250000 non-null  object
#  12  Churn                  250000 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 24.8+ MB

# %% [markdown]
#  This info() command is used to retrieve the information i.e., whether the data has null values or not and datatype of eacch columns

# %%
df.isnull().sum()
# Out:
# Customer ID                  0
# Purchase Date                0
# Product Category             0
# Product Price                0
# Quantity                     0
# Total Purchase Amount        0
# Payment Method               0
# Customer Age                 0
# Returns                  47596
# Customer Name                0
# Age                          0
# Gender                       0
# Churn                        0
# dtype: int64

# %% [markdown]
#  By using isnull() we can identify null values and by using sum() we can find sum.

# %%
df.describe()
# Out:
#         Customer ID  Product Price       Quantity  Total Purchase Amount  \
# count  250000.00000  250000.000000  250000.000000          250000.000000
# mean    25004.03624     254.659512       2.998896            2725.370732
# std     14428.27959     141.568577       1.414694            1442.933565
# min         1.00000      10.000000       1.000000             100.000000
# 25%     12497.75000     132.000000       2.000000            1477.000000
# 50%     25018.00000     255.000000       3.000000            2724.000000
# 75%     37506.00000     377.000000       4.000000            3974.000000
# max     50000.00000     500.000000       5.000000            5350.000000
#
#         Customer Age        Returns            Age          Churn
# count  250000.000000  202404.000000  250000.000000  250000.000000
# mean       43.940528       0.497861      43.940528       0.199496
# std        15.350246       0.499997      15.350246       0.399622
# ...

# %% [markdown]
#  This describe(include='object') command used to display the count,unique values,top ,freq of each object in our  data

# %%
df.isnull().sum()
# Out:
# Customer ID                  0
# Purchase Date                0
# Product Category             0
# Product Price                0
# Quantity                     0
# Total Purchase Amount        0
# Payment Method               0
# Customer Age                 0
# Returns                  47596
# Customer Name                0
# Age                          0
# Gender                       0
# Churn                        0
# dtype: int64

# %% [markdown]
#  By using isnull() we can identify null values and by using sum() we can find sum.

# %%
df['Product Category'].value_counts()
# Out:
# Product Category
# Clothing       75052
# Books          74912
# Electronics    50185
# Home           49851
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Customer ID', 'Purchase Date', 'Product Category', 'Product Price',
#        'Quantity', 'Total Purchase Amount', 'Payment Method', 'Customer Age',
#        'Returns', 'Customer Name', 'Age', 'Gender', 'Churn'],
#       dtype='object')

# %% [markdown]
# columns command shows the column names

# %%
df.shape
# Out:
# (250000, 13)

# %% [markdown]
# # Histogram

# %% [markdown]
# # countplot
#
# countplot function, you can achieve a similar result using a combination of value_counts() and bar().A countplot is a type of plot used to visualize the frequency of categorical data. It is particularly useful when you want to understand the distribution of different categories within a dataset. The countplot shows the count of observations in each categorical bin using bars.

# %%
sns.countplot(x='Product Category', data=df)

plt.xlabel('products')
plt.ylabel('Count')
plt.title('Product Counts')
# Out:
# Text(0.5, 1.0, 'Product Counts')

# %% [markdown]
# It shows the countplot of products column.

# %%
sns.countplot(x='Gender', data=df)


plt.ylabel('Count')
plt.title('Gender')

print(df['Gender'].value_counts())
# Out:
# Gender
# Female    125560
# Male      124440
# Name: count, dtype: int64

# %% [markdown]
# It shows the countplot of Gender column.

# %%
sns.countplot(x='Payment Method', data=df)
plt.ylabel('Count')
plt.title('Payment Method')
(df['Payment Method'].value_counts())
# Out:
# Payment Method
# Credit Card    100486
# PayPal          74837
# Cash            49894
# Crypto          24783
# Name: count, dtype: int64

# %% [markdown]
#  It shows the countplot of payment method column.

# %%
category_counts = df['Product Category'].value_counts()
explode=[0,0.1,0,0]
plt.pie(category_counts.values, labels=category_counts.index, autopct='%1.1f%%',explode=explode,shadow=True)
plt.title('Distribution of Product Categories')

plt.show()

# %% [markdown]
#  The above pie chart shows the how much percentage have Distribution of Product Categories  in dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          250000 non-null  object
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   Payment Method         250000 non-null  object
#  7   Customer Age           250000 non-null  int64
#  8   Returns                202404 non-null  float64
#  9   Customer Name          250000 non-null  object
#  10  Age                    250000 non-null  int64
#  11  Gender                 250000 non-null  object
#  12  Churn                  250000 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 24.8+ MB

# %% [markdown]
#  This info() command is used to retrieve the information i.e., whether the data has null values or not and datatype of eacch columns

# %%
df['Purchase Date'] = pd.to_datetime(df['Purchase Date'])
df['year'] = df['Purchase Date'].dt.year
df['month']= df['Purchase Date'].dt.month
df['month_name']= df['Purchase Date'].dt.month_name()
df['day']= df['Purchase Date'].dt.date

plt.show()

# %%
df.head()
# Out:
#    Customer ID       Purchase Date Product Category  Product Price  Quantity  \
# 0        46251 2020-09-08 09:38:32      Electronics             12         3
# 1        46251 2022-03-05 12:56:35             Home            468         4
# 2        46251 2022-05-23 18:18:01             Home            288         2
# 3        46251 2020-11-12 13:13:29         Clothing            196         1
# 4        13593 2020-11-27 17:55:11             Home            449         1
#
#    Total Purchase Amount Payment Method  Customer Age  Returns  \
# 0                    740    Credit Card            37      0.0
# 1                   2739         PayPal            37      0.0
# 2                   3196         PayPal            37      0.0
# 3                   3509         PayPal            37      0.0
# 4                   3452    Credit Card            49      0.0
#
#          Customer Name  Age  Gender  Churn  year  month month_name         day
# ...

# %% [markdown]
#  we use the head() command to retrieve the first 5 rows of ecommerce_customer_data_custom_ratios our data.

# %%
x=df['year'].value_counts()


total_purchase_by_year = df.groupby('year')['Total Purchase Amount'].sum()
total_purchase_by_year=(total_purchase_by_year/df['Total Purchase Amount'].sum())*100
colour=['Blue']
plt.bar(x.index,total_purchase_by_year/df['Total Purchase Amount'].sum())*100

plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Purchase Amount', fontsize=12)
plt.title('Total Purchase Amount by Year', fontsize=14)
plt.xticks(rotation=45, ha='right')

plt.show()

# %%
Category = df.groupby('Product Category')['Total Purchase Amount'].sum()
Category=(Category/df['Total Purchase Amount'].sum())*100
print(Category)
# Out:
# Product Category
# Books          30.078785
# Clothing       30.019021
# Electronics    20.048570
# Home           19.853623
# Name: Total Purchase Amount, dtype: float64

# %%
colour=['Red','Green','Blue','Orange']
plt.bar(Category.index, Category, color=colour, edgecolor='black')
for i, value in enumerate(Category):
    plt.text(i, value / 2, f'{value:.1f}%', ha='center', va='center', color='white', fontsize=12)

# %% [markdown]
# # Boxplot
# A boxplot (also known as a whisker plot) is a powerful visualization tool used to display the distribution of a dataset and identify potential outliers. It provides a summary of one or more continuous variables, including their median, quartiles, and potential outliers.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Product Category', y='Total Purchase Amount',hue='Gender', data=df)
# Out:
# <Axes: xlabel='Product Category', ylabel='Total Purchase Amount'>

# %%
Month_Purchase = df.groupby('month')['Total Purchase Amount'].sum()
Month_Purchase=Month_Purchase/1000
print(Month_Purchase)
# Out:
# month
# 1     62377.969
# 2     57343.030
# 3     63190.828
# 4     59611.906
# 5     62044.880
# 6     60487.756
# 7     62641.624
# 8     62454.400
# 9     52046.626
# 10    46705.059
# 11    45655.744
# 12    46782.861
# Name: Total Purchase Amount, dtype: float64

# %%
colour = sns.color_palette("husl", 12)

plt.bar(Month_Purchase.index, Month_Purchase, color=colour, edgecolor='black')

for i, value in enumerate(Month_Purchase):
    plt.text(i+1, value / 2, round(value, 2), ha='center', va='center', color='white', fontsize=12,rotation=90)

plt.xticks(ticks=range(1, 13), rotation=45, fontsize=10)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total Purchase Amount', fontsize=12)
plt.title('Total Purchase Amount by Month', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Total Purchase Amount by Month')

# %%
Gender_spent = df.groupby('Gender')['Total Purchase Amount'].sum()
print(Gender_spent)
# Out:
# Gender
# Female    342462421
# Male      338880262
# Name: Total Purchase Amount, dtype: int64

# %% [markdown]
# # Scatter plot

# %%
new_df = df.head(300)
m = new_df['Total Purchase Amount'] / 100

np.random.seed(0)
sizes = np.random.uniform(20, 100, size=len(new_df))

plt.figure(figsize=(10, 6))
scatter = plt.scatter(x=new_df['Age'], y=m, c=m, cmap='summer', edgecolor='k', s=sizes, alpha=0.7)

plt.colorbar(scatter, label='Total Purchase Amount (normalized)')
plt.xlabel('Age', fontsize=12)
plt.ylabel('Total Purchase Amount (normalized)', fontsize=12)
plt.title('Scatterplot of Age vs Normalized Total Purchase Amount', fontsize=14)

plt.show()

# %% [markdown]
# # HeatMap

# %%
x=df.pivot_table(index='year',columns='month',values='Total Purchase Amount')

# %%
sns.heatmap(x)
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %% [markdown]
# sns is a shorthand of seaborn.Here we are plotting heatmap.Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix.

# %%
df['Day_name']= df['Purchase Date'].dt.day_name()

# %%
df['Day_name'][0]
# Out:
# 'Tuesday'

# %%
import numpy as np
df['Weekend'] = np.where((df['Day_name'] == 'Saturday') | (df['Day_name'] == 'Sunday'), 1, 0)

# %%
Weekely_analysis = df.groupby('Weekend')['Total Purchase Amount'].sum()
Weekely_analysis.index = Weekely_analysis.index.map({0: 'Not Weekend', 1: 'Weekend'})
(Weekely_analysis)
# Out:
# Weekend
# Not Weekend    487800567
# Weekend        193542116
# Name: Total Purchase Amount, dtype: int64

# %%
import matplotlib.pyplot as plt

text = ' '.join(df['Customer Name'].dropna())

wordcloud = WordCloud(width=700, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# In the context of Exploratory Data Analysis (EDA) on e-commerce customer data, custom ratios can provide insightful conclusions. Here’s a general framework for summarizing such an analysis:
#
# 1. **Customer Segmentation**: By analyzing custom ratios, you might uncover different segments within your customer base, such as high-value customers versus low-value ones. This helps in targeted marketing and personalized customer service.
#
# 2. **Purchase Patterns**: Ratios like average order value to purchase frequency can reveal patterns in buying behavior, helping you understand how often and how much different customer groups spend.
#
# 3. **Customer Retention**: Ratios that involve repeat purchases or time between purchases can give insights into customer loyalty and retention rates, allowing for strategies to improve these metrics.
#
# 4. **Revenue Generation**: Custom ratios such as revenue per customer or customer lifetime value can indicate which segments are most profitable and highlight areas for potential revenue growth.
#
# 5. **Churn Analysis**: Ratios that track changes in customer behavior over time can identify signs of churn and help in developing retention strategies.
#
# 6. **Marketing Effectiveness**: Comparing ratios before and after marketing campaigns can help measure the effectiveness of those campaigns.
#
# In summary, custom ratios in EDA can reveal key insights about customer behavior, profitability, and the effectiveness of marketing strategies, guiding data-driven decision-making for e-commerce businesses.

# %% [markdown]
# # Happy Learning! 📚✨

# %% [markdown]
# # Thank you.
